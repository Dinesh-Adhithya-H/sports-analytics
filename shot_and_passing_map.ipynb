# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
length=120
width=80

# %%
match_id=69301
home_team_required="England Women's"
away_team_required="Sweden Women's"

# %%
with open("Statsbomb/events/69301.json") as data_file:
    data=json.load(data_file)

# %%
data
# Out:
# [{'id': 'e8643796-c76d-44f5-a03d-fa742e051942',
#   'index': 1,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 35, 'name': 'Starting XI'},
#   'possession': 1,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'duration': 0.0,
#   'tactics': {'formation': 4141,
#    'lineup': [{'player': {'id': 19421, 'name': 'Carly Mitchell Telford'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'jersey_number': 13},
#     {'player': {'id': 10178, 'name': 'Lucy Bronze'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'jersey_number': 2},
#     {'player': {'id': 10185, 'name': 'Stephanie Houghton'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'jersey_number': 5},
#     {'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'jersey_number': 15},
#     {'player': {'id': 10252, 'name': 'Alex Greenwood'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'jersey_number': 3},
#     {'player': {'id': 10190, 'name': 'Jade Moore'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'jersey_number': 16},
#     {'player': {'id': 4654, 'name': 'Nikita Parris'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'jersey_number': 7},
#     {'player': {'id': 10172, 'name': 'Jill Scott'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'jersey_number': 8},
#     {'player': {'id': 4641, 'name': 'Francesca Kirby'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'jersey_number': 10},
#     {'player': {'id': 15619, 'name': 'Bethany Mead'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'jersey_number': 22},
#     {'player': {'id': 10180, 'name': 'Ellen White'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'jersey_number': 18}]}},
#  {'id': '937f83f8-674d-4c58-81d5-e2101a9f2e60',
#   'index': 2,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 35, 'name': 'Starting XI'},
#   'possession': 1,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'duration': 0.0,
#   'tactics': {'formation': 4231,
#    'lineup': [{'player': {'id': 4640, 'name': 'Rut Hedvig Lindahl'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'jersey_number': 1},
#     {'player': {'id': 24693, 'name': 'Hanna Glas'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'jersey_number': 4},
#     {'player': {'id': 10375, 'name': 'Nilla Fischer'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'jersey_number': 5},
#     {'player': {'id': 10230, 'name': 'Linda Brigitta Sembrant'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'jersey_number': 3},
#     {'player': {'id': 4633, 'name': 'Magdalena Ericsson'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'jersey_number': 6},
#     {'player': {'id': 26093, 'name': 'Nathalie Bj̦rn'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'jersey_number': 15},
#     {'player': {'id': 10224, 'name': 'Sara Caroline Seger'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'jersey_number': 17},
#     {'player': {'id': 13881, 'name': 'Eva Sofia Jakobsson'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'jersey_number': 10},
#     {'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#      'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#      'jersey_number': 9},
#     {'player': {'id': 10215, 'name': 'Fridolina Rolf̦'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'jersey_number': 18},
#     {'player': {'id': 10229, 'name': 'Stina Blackstenius'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'jersey_number': 11}]}},
#  {'id': '87ba272a-3af0-4fc7-872f-65e8f79fb753',
#   'index': 3,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 18, 'name': 'Half Start'},
#   'possession': 1,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'duration': 0.0,
#   'related_events': ['85d30bef-8b77-405e-bc64-c63ed4d7a6d7']},
#  {'id': '85d30bef-8b77-405e-bc64-c63ed4d7a6d7',
#   'index': 4,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 18, 'name': 'Half Start'},
#   'possession': 1,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'duration': 0.0,
#   'related_events': ['87ba272a-3af0-4fc7-872f-65e8f79fb753']},
#  {'id': '760528a6-2de2-427f-9795-b2b19819ef1f',
#   'index': 5,
#   'period': 1,
#   'timestamp': '00:00:00.140',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10180, 'name': 'Ellen White'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [60.0, 40.0],
#   'duration': 0.16873,
#   'related_events': ['f10b0eba-c74d-4ea3-8355-13e4cd263c6f'],
#   'pass': {'recipient': {'id': 4641, 'name': 'Francesca Kirby'},
#    'length': 2.1023796,
#    'angle': 0.44237423,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [61.9, 40.9],
#    'type': {'id': 65, 'name': 'Kick Off'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'f10b0eba-c74d-4ea3-8355-13e4cd263c6f',
#   'index': 6,
#   'period': 1,
#   'timestamp': '00:00:00.308',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4641, 'name': 'Francesca Kirby'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [61.9, 40.9],
#   'related_events': ['760528a6-2de2-427f-9795-b2b19819ef1f']},
#  {'id': '608e76cf-d831-4182-b338-72f365cb9eeb',
#   'index': 7,
#   'period': 1,
#   'timestamp': '00:00:00.308',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4641, 'name': 'Francesca Kirby'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [61.9, 40.9],
#   'duration': 4.83507,
#   'under_pressure': True,
#   'related_events': ['e85776b5-4480-4548-b4c3-3f1789c7dd59',
#    'ecec23b8-f03d-4bee-80df-9fabec558187',
#    'f10b0eba-c74d-4ea3-8355-13e4cd263c6f'],
#   'carry': {'end_location': [82.6, 37.6]}},
#  {'id': 'e85776b5-4480-4548-b4c3-3f1789c7dd59',
#   'index': 8,
#   'period': 1,
#   'timestamp': '00:00:04.675',
#   'minute': 0,
#   'second': 4,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10215, 'name': 'Fridolina Rolf̦'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [35.2, 40.6],
#   'duration': 0.362897,
#   'related_events': ['608e76cf-d831-4182-b338-72f365cb9eeb']},
#  {'id': 'ecec23b8-f03d-4bee-80df-9fabec558187',
#   'index': 9,
#   'period': 1,
#   'timestamp': '00:00:05.143',
#   'minute': 0,
#   'second': 5,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4641, 'name': 'Francesca Kirby'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [82.6, 37.6],
#   'duration': 1.173625,
#   'related_events': ['ebb46045-f1ab-4c25-88b8-fc7ea165b52d'],
#   'pass': {'recipient': {'id': 10178, 'name': 'Lucy Bronze'},
#    'length': 21.317833,
#    'angle': 1.7691119,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [78.4, 58.5],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'ebb46045-f1ab-4c25-88b8-fc7ea165b52d',
#   'index': 10,
#   'period': 1,
#   'timestamp': '00:00:06.317',
#   'minute': 0,
#   'second': 6,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10178, 'name': 'Lucy Bronze'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [78.4, 58.5],
#   'related_events': ['ecec23b8-f03d-4bee-80df-9fabec558187']},
#  {'id': '4c304b15-1daf-4ce3-acd8-eb4f072691a2',
#   'index': 11,
#   'period': 1,
#   'timestamp': '00:00:06.317',
#   'minute': 0,
#   'second': 6,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10178, 'name': 'Lucy Bronze'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [78.4, 58.5],
#   'duration': 1.527075,
#   'related_events': ['bdedb943-ddac-42ab-bc8b-756faa49d9e6',
#    'ebb46045-f1ab-4c25-88b8-fc7ea165b52d'],
#   'carry': {'end_location': [84.7, 65.3]}},
#  {'id': 'bdedb943-ddac-42ab-bc8b-756faa49d9e6',
#   'index': 12,
#   'period': 1,
#   'timestamp': '00:00:07.844',
#   'minute': 0,
#   'second': 7,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10178, 'name': 'Lucy Bronze'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [84.7, 65.3],
#   'duration': 1.0191,
#   'related_events': ['a17df3fd-d85c-4982-b112-b43aef968b9b'],
#   'pass': {'recipient': {'id': 4654, 'name': 'Nikita Parris'},
#    'length': 18.984203,
#    'angle': 0.72576743,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [98.9, 77.9],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'a17df3fd-d85c-4982-b112-b43aef968b9b',
#   'index': 13,
#   'period': 1,
#   'timestamp': '00:00:08.863',
#   'minute': 0,
#   'second': 8,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4654, 'name': 'Nikita Parris'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'location': [98.9, 77.9],
#   'related_events': ['bdedb943-ddac-42ab-bc8b-756faa49d9e6']},
#  {'id': 'ccd0ed8d-5c0c-4124-8a70-97b5c2ff1850',
#   'index': 14,
#   'period': 1,
#   'timestamp': '00:00:08.863',
#   'minute': 0,
#   'second': 8,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4654, 'name': 'Nikita Parris'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'location': [98.9, 77.9],
#   'duration': 1.7226,
#   'related_events': ['456a1ae6-1fe8-4ffc-952b-152a7f89e1d2',
#    'a17df3fd-d85c-4982-b112-b43aef968b9b'],
#   'carry': {'end_location': [94.7, 75.5]}},
#  {'id': '456a1ae6-1fe8-4ffc-952b-152a7f89e1d2',
#   'index': 15,
#   'period': 1,
#   'timestamp': '00:00:10.586',
#   'minute': 0,
#   'second': 10,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4654, 'name': 'Nikita Parris'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'location': [94.7, 75.5],
#   'duration': 0.7,
#   'related_events': ['0b9e78ec-31bb-4641-89e8-c2b5fb1a838c'],
#   'pass': {'recipient': {'id': 10172, 'name': 'Jill Scott'},
#    'length': 11.287161,
#    'angle': -1.6951513,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [93.3, 64.3],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '39c016bc-47cc-4511-9833-d64c68dc05a1',
#   'index': 16,
#   'period': 1,
#   'timestamp': '00:00:10.928',
#   'minute': 0,
#   'second': 10,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10224, 'name': 'Sara Caroline Seger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [22.8, 19.0],
#   'duration': 0.338841},
#  {'id': '0b9e78ec-31bb-4641-89e8-c2b5fb1a838c',
#   'index': 17,
#   'period': 1,
#   'timestamp': '00:00:11.286',
#   'minute': 0,
#   'second': 11,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10172, 'name': 'Jill Scott'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [93.3, 64.3],
#   'related_events': ['456a1ae6-1fe8-4ffc-952b-152a7f89e1d2']},
#  {'id': 'af464de6-63ee-44de-b2f5-1454ce915beb',
#   'index': 18,
#   'period': 1,
#   'timestamp': '00:00:11.286',
#   'minute': 0,
#   'second': 11,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10172, 'name': 'Jill Scott'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [93.3, 64.3],
#   'duration': 0.04,
#   'related_events': ['0b9e78ec-31bb-4641-89e8-c2b5fb1a838c',
#    'a8d0155f-260c-4470-b842-b474ea58ffa7'],
#   'carry': {'end_location': [94.2, 64.6]}},
#  {'id': 'a8d0155f-260c-4470-b842-b474ea58ffa7',
#   'index': 19,
#   'period': 1,
#   'timestamp': '00:00:11.326',
#   'minute': 0,
#   'second': 11,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10172, 'name': 'Jill Scott'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [94.2, 64.6],
#   'duration': 4.15,
#   'related_events': ['170be075-3fa5-45dd-90cc-be8ca6405be2'],
#   'pass': {'length': 25.223997,
#    'angle': -0.4033301,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [117.4, 54.7],
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '170be075-3fa5-45dd-90cc-be8ca6405be2',
#   'index': 20,
#   'period': 1,
#   'timestamp': '00:00:15.476',
#   'minute': 0,
#   'second': 15,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 4640, 'name': 'Rut Hedvig Lindahl'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [3.6, 26.3],
#   'duration': 0.0,
#   'related_events': ['a8d0155f-260c-4470-b842-b474ea58ffa7']},
#  {'id': 'a8d65993-7482-4238-8bfb-b9dc62610be8',
#   'index': 21,
#   'period': 1,
#   'timestamp': '00:00:15.476',
#   'minute': 0,
#   'second': 15,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 4640, 'name': 'Rut Hedvig Lindahl'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [3.6, 26.3],
#   'duration': 11.1806,
#   'related_events': ['170be075-3fa5-45dd-90cc-be8ca6405be2',
#    'bf1317e6-d896-4a09-862d-876c2f963772'],
#   'carry': {'end_location': [13.4, 38.9]}},
#  {'id': 'bf1317e6-d896-4a09-862d-876c2f963772',
#   'index': 22,
#   'period': 1,
#   'timestamp': '00:00:26.656',
#   'minute': 0,
#   'second': 26,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 4640, 'name': 'Rut Hedvig Lindahl'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [13.4, 38.9],
#   'duration': 1.547657,
#   'related_events': ['457315eb-6b0e-41a7-a32c-d44fb1b1bcb8'],
#   'pass': {'recipient': {'id': 10375, 'name': 'Nilla Fischer'},
#    'length': 20.44138,
#    'angle': 1.4531159,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [15.8, 59.2],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': '457315eb-6b0e-41a7-a32c-d44fb1b1bcb8',
#   'index': 23,
#   'period': 1,
#   'timestamp': '00:00:28.204',
#   'minute': 0,
#   'second': 28,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10375, 'name': 'Nilla Fischer'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [15.8, 59.2],
#   'related_events': ['bf1317e6-d896-4a09-862d-876c2f963772']},
#  {'id': 'cffa9628-4914-402e-8041-74541bdb3357',
#   'index': 24,
#   'period': 1,
#   'timestamp': '00:00:28.204',
#   'minute': 0,
#   'second': 28,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10375, 'name': 'Nilla Fischer'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [15.8, 59.2],
#   'duration': 1.550743,
#   'related_events': ['457315eb-6b0e-41a7-a32c-d44fb1b1bcb8',
#    'f1feda61-3e0a-4ca3-81c4-4bd289db647d'],
#   'carry': {'end_location': [24.7, 64.1]}},
#  {'id': 'f1feda61-3e0a-4ca3-81c4-4bd289db647d',
#   'index': 25,
#   'period': 1,
#   'timestamp': '00:00:29.755',
#   'minute': 0,
#   'second': 29,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10375, 'name': 'Nilla Fischer'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [24.7, 64.1],
#   'duration': 1.3454,
#   'related_events': ['bc07de9e-2259-4b16-bf74-f4722af77b55'],
#   'pass': {'recipient': {'id': 24693, 'name': 'Hanna Glas'},
#    'length': 16.62438,
#    'angle': 0.8151766,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [36.1, 76.2],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'bc07de9e-2259-4b16-bf74-f4722af77b55',
#   'index': 26,
#   'period': 1,
#   'timestamp': '00:00:31.100',
#   'minute': 0,
#   'second': 31,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [36.1, 76.2],
#   'related_events': ['f1feda61-3e0a-4ca3-81c4-4bd289db647d']},
#  {'id': '0aba3e49-c9b4-4f25-8dcd-bdabbcf91dd3',
#   'index': 27,
#   'period': 1,
#   'timestamp': '00:00:31.100',
#   'minute': 0,
#   'second': 31,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [36.1, 76.2],
#   'duration': 2.3262,
#   'related_events': ['75d2e1d2-1b1e-4ada-b004-574cfc138a56',
#    'bc07de9e-2259-4b16-bf74-f4722af77b55'],
#   'carry': {'end_location': [36.1, 76.2]}},
#  {'id': '75d2e1d2-1b1e-4ada-b004-574cfc138a56',
#   'index': 28,
#   'period': 1,
#   'timestamp': '00:00:33.426',
#   'minute': 0,
#   'second': 33,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [36.1, 76.2],
#   'duration': 0.92867,
#   'related_events': ['c80d1016-6eed-4fed-b2e9-5fe46744e5d0'],
#   'pass': {'recipient': {'id': 10375, 'name': 'Nilla Fischer'},
#    'length': 9.302151,
#    'angle': -3.1200905,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [26.8, 76.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'c80d1016-6eed-4fed-b2e9-5fe46744e5d0',
#   'index': 29,
#   'period': 1,
#   'timestamp': '00:00:34.355',
#   'minute': 0,
#   'second': 34,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10375, 'name': 'Nilla Fischer'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [26.8, 76.0],
#   'related_events': ['75d2e1d2-1b1e-4ada-b004-574cfc138a56']},
#  {'id': 'eaabbc5a-8fbc-4b36-b215-5980b16986d2',
#   'index': 30,
#   'period': 1,
#   'timestamp': '00:00:34.355',
#   'minute': 0,
#   'second': 34,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10375, 'name': 'Nilla Fischer'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [26.8, 76.0],
#   'duration': 2.67803,
#   'under_pressure': True,
#   'related_events': ['b69d6e5a-dfc8-460f-a2c1-3177d573260a',
#    'c80d1016-6eed-4fed-b2e9-5fe46744e5d0',
#    'e6586376-165e-43e3-b018-deba55ec9a72'],
#   'carry': {'end_location': [33.5, 76.5]}},
#  {'id': 'e6586376-165e-43e3-b018-deba55ec9a72',
#   'index': 31,
#   'period': 1,
#   'timestamp': '00:00:35.364',
#   'minute': 0,
#   'second': 35,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10180, 'name': 'Ellen White'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [88.6, 13.6],
#   'duration': 1.52028,
#   'related_events': ['eaabbc5a-8fbc-4b36-b215-5980b16986d2']},
#  {'id': 'b69d6e5a-dfc8-460f-a2c1-3177d573260a',
#   'index': 32,
#   'period': 1,
#   'timestamp': '00:00:37.033',
#   'minute': 0,
#   'second': 37,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10375, 'name': 'Nilla Fischer'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [33.5, 76.5],
#   'duration': 1.598765,
#   'related_events': ['6067f54b-fd2e-4d48-a342-60fae3521cdd'],
#   'pass': {'recipient': {'id': 10220, 'name': 'Kosovare Asllani'},
#    'length': 39.28422,
#    'angle': -0.09688244,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [72.6, 72.7],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '6067f54b-fd2e-4d48-a342-60fae3521cdd',
#   'index': 33,
#   'period': 1,
#   'timestamp': '00:00:38.632',
#   'minute': 0,
#   'second': 38,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [72.6, 72.7],
#   'related_events': ['b69d6e5a-dfc8-460f-a2c1-3177d573260a']},
#  {'id': '94f38221-2d64-4a84-86f3-eb98f00f8603',
#   'index': 34,
#   'period': 1,
#   'timestamp': '00:00:38.632',
#   'minute': 0,
#   'second': 38,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [72.6, 72.7],
#   'duration': 1.335835,
#   'under_pressure': True,
#   'related_events': ['14a30d6d-52b5-4a4c-913f-1af87b9cdf65',
#    '6067f54b-fd2e-4d48-a342-60fae3521cdd',
#    '7f5dce6f-bfd2-46b7-bfb0-bf0f81bbccd4'],
#   'carry': {'end_location': [74.4, 77.4]}},
#  {'id': '7f5dce6f-bfd2-46b7-bfb0-bf0f81bbccd4',
#   'index': 35,
#   'period': 1,
#   'timestamp': '00:00:39.195',
#   'minute': 0,
#   'second': 39,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10190, 'name': 'Jade Moore'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [50.1, 15.0],
#   'duration': 1.276456,
#   'related_events': ['14a30d6d-52b5-4a4c-913f-1af87b9cdf65',
#    '94f38221-2d64-4a84-86f3-eb98f00f8603']},
#  {'id': '14a30d6d-52b5-4a4c-913f-1af87b9cdf65',
#   'index': 36,
#   'period': 1,
#   'timestamp': '00:00:39.968',
#   'minute': 0,
#   'second': 39,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [74.4, 77.4],
#   'duration': 3.3614,
#   'under_pressure': True,
#   'related_events': ['7f5dce6f-bfd2-46b7-bfb0-bf0f81bbccd4',
#    'd7757537-0a24-4365-859d-79e045da4d94',
#    'e4e06886-8608-416c-ab58-98cb01fbbce0'],
#   'pass': {'recipient': {'id': 13881, 'name': 'Eva Sofia Jakobsson'},
#    'length': 26.2,
#    'angle': 0.0,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [100.6, 77.4],
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'e4e06886-8608-416c-ab58-98cb01fbbce0',
#   'index': 37,
#   'period': 1,
#   'timestamp': '00:00:43.329',
#   'minute': 0,
#   'second': 43,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 13881, 'name': 'Eva Sofia Jakobsson'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [94.5, 78.4],
#   'related_events': ['14a30d6d-52b5-4a4c-913f-1af87b9cdf65'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'd7757537-0a24-4365-859d-79e045da4d94',
#   'index': 38,
#   'period': 1,
#   'timestamp': '00:00:43.329',
#   'minute': 0,
#   'second': 43,
#   'type': {'id': 9, 'name': 'Clearance'},
#   'possession': 3,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'out': True,
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4648, 'name': 'Abbie McManus'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [20.4, 3.6],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['14a30d6d-52b5-4a4c-913f-1af87b9cdf65'],
#   'clearance': {'left_foot': True,
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': 'cd6a8d3b-8322-487a-96ef-f7f6921fb175',
#   'index': 39,
#   'period': 1,
#   'timestamp': '00:00:57.167',
#   'minute': 0,
#   'second': 57,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [101.5, 80.0],
#   'duration': 1.05006,
#   'related_events': ['cc6369b7-87d2-4801-8ab9-f903714e05cf'],
#   'pass': {'recipient': {'id': 10220, 'name': 'Kosovare Asllani'},
#    'length': 8.146778,
#    'angle': -0.7246036,
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'end_location': [107.6, 74.6],
#    'type': {'id': 67, 'name': 'Throw-in'}}},
#  {'id': 'cc6369b7-87d2-4801-8ab9-f903714e05cf',
#   'index': 40,
#   'period': 1,
#   'timestamp': '00:00:58.217',
#   'minute': 0,
#   'second': 58,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [107.6, 74.6],
#   'related_events': ['cd6a8d3b-8322-487a-96ef-f7f6921fb175']},
#  {'id': '8ab14d4f-52a3-4124-91b2-c1903387038a',
#   'index': 41,
#   'period': 1,
#   'timestamp': '00:00:58.217',
#   'minute': 0,
#   'second': 58,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [107.6, 74.6],
#   'duration': 1.0569,
#   'related_events': ['72eab7d7-76cf-4303-a48c-57ad238db687'],
#   'pass': {'recipient': {'id': 24693, 'name': 'Hanna Glas'},
#    'length': 7.3573093,
#    'angle': 2.5988421,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [101.3, 78.4],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '72eab7d7-76cf-4303-a48c-57ad238db687',
#   'index': 42,
#   'period': 1,
#   'timestamp': '00:00:59.274',
#   'minute': 0,
#   'second': 59,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [101.3, 78.4],
#   'related_events': ['8ab14d4f-52a3-4124-91b2-c1903387038a']},
#  {'id': '6977ae1d-4681-421b-84c0-7ca215cb9a03',
#   'index': 43,
#   'period': 1,
#   'timestamp': '00:00:59.274',
#   'minute': 0,
#   'second': 59,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [101.3, 78.4],
#   'duration': 0.6686,
#   'related_events': ['72eab7d7-76cf-4303-a48c-57ad238db687',
#    'a1c30e06-ab90-456e-b179-741e79fe2482'],
#   'carry': {'end_location': [101.5, 78.1]}},
#  {'id': 'a1c30e06-ab90-456e-b179-741e79fe2482',
#   'index': 44,
#   'period': 1,
#   'timestamp': '00:00:59.943',
#   'minute': 0,
#   'second': 59,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [101.5, 78.1],
#   'duration': 0.575728,
#   'related_events': ['6bdc5945-58e3-429f-b6a2-9e414e1cc610'],
#   'pass': {'recipient': {'id': 10220, 'name': 'Kosovare Asllani'},
#    'length': 6.3126855,
#    'angle': -0.06340695,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [107.8, 77.7],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': 'bb408e9d-e90f-4812-9f5c-b661463465aa',
#   'index': 45,
#   'period': 1,
#   'timestamp': '00:01:00.274',
#   'minute': 1,
#   'second': 0,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 15619, 'name': 'Bethany Mead'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'location': [12.9, 9.7],
#   'duration': 2.080666,
#   'related_events': ['48668da6-831f-4fa0-b6cc-f579aea74160',
#    '6bdc5945-58e3-429f-b6a2-9e414e1cc610',
#    '8b82c29c-979d-4fdc-b6e7-0978695c3e4a']},
#  {'id': '6bdc5945-58e3-429f-b6a2-9e414e1cc610',
#   'index': 46,
#   'period': 1,
#   'timestamp': '00:01:00.518',
#   'minute': 1,
#   'second': 0,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [107.8, 77.7],
#   'under_pressure': True,
#   'related_events': ['a1c30e06-ab90-456e-b179-741e79fe2482',
#    'bb408e9d-e90f-4812-9f5c-b661463465aa']},
#  {'id': '48668da6-831f-4fa0-b6cc-f579aea74160',
#   'index': 47,
#   'period': 1,
#   'timestamp': '00:01:00.518',
#   'minute': 1,
#   'second': 0,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [107.8, 77.7],
#   'duration': 1.522472,
#   'under_pressure': True,
#   'related_events': ['6bdc5945-58e3-429f-b6a2-9e414e1cc610',
#    '8b82c29c-979d-4fdc-b6e7-0978695c3e4a',
#    'bb408e9d-e90f-4812-9f5c-b661463465aa'],
#   'carry': {'end_location': [106.9, 77.7]}},
#  {'id': '8b82c29c-979d-4fdc-b6e7-0978695c3e4a',
#   'index': 48,
#   'period': 1,
#   'timestamp': '00:01:02.041',
#   'minute': 1,
#   'second': 2,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10220, 'name': 'Kosovare Asllani'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [106.9, 77.7],
#   'duration': 2.0129,
#   'under_pressure': True,
#   'related_events': ['bb408e9d-e90f-4812-9f5c-b661463465aa',
#    'fd93129a-1b88-4643-83af-c19d712a97ae'],
#   'pass': {'recipient': {'id': 24693, 'name': 'Hanna Glas'},
#    'length': 11.423659,
#    'angle': -0.4048918,
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'end_location': [117.4, 73.2],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'f484262f-987a-4c46-83bc-f9d6c61f8a76',
#   'index': 49,
#   'period': 1,
#   'timestamp': '00:01:03.015',
#   'minute': 1,
#   'second': 3,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [8.3, 11.3],
#   'duration': 1.153299,
#   'related_events': ['664c6372-a033-4ed8-9792-882583b9a32c',
#    '6b396a68-71f7-447c-b4f6-f2c07655cbe2',
#    'fd93129a-1b88-4643-83af-c19d712a97ae']},
#  {'id': 'fd93129a-1b88-4643-83af-c19d712a97ae',
#   'index': 50,
#   'period': 1,
#   'timestamp': '00:01:04.054',
#   'minute': 1,
#   'second': 4,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [117.4, 73.2],
#   'under_pressure': True,
#   'related_events': ['8b82c29c-979d-4fdc-b6e7-0978695c3e4a',
#    'f484262f-987a-4c46-83bc-f9d6c61f8a76']},
#  {'id': '664c6372-a033-4ed8-9792-882583b9a32c',
#   'index': 51,
#   'period': 1,
#   'timestamp': '00:01:04.054',
#   'minute': 1,
#   'second': 4,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [117.4, 73.2],
#   'duration': 0.0822,
#   'under_pressure': True,
#   'related_events': ['6b396a68-71f7-447c-b4f6-f2c07655cbe2',
#    'f484262f-987a-4c46-83bc-f9d6c61f8a76',
#    'fd93129a-1b88-4643-83af-c19d712a97ae'],
#   'carry': {'end_location': [117.4, 74.8]}},
#  {'id': '6b396a68-71f7-447c-b4f6-f2c07655cbe2',
#   'index': 52,
#   'period': 1,
#   'timestamp': '00:01:04.136',
#   'minute': 1,
#   'second': 4,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [117.4, 74.8],
#   'duration': 0.112299,
#   'under_pressure': True,
#   'related_events': ['03c68d0b-b73e-4124-809b-77bf198e8d52',
#    'f484262f-987a-4c46-83bc-f9d6c61f8a76'],
#   'pass': {'length': 1.6763054,
#    'angle': -1.2679114,
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'end_location': [117.9, 73.2],
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '03c68d0b-b73e-4124-809b-77bf198e8d52',
#   'index': 53,
#   'period': 1,
#   'timestamp': '00:01:04.248',
#   'minute': 1,
#   'second': 4,
#   'type': {'id': 6, 'name': 'Block'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [3.1, 7.8],
#   'duration': 0.0,
#   'related_events': ['6b396a68-71f7-447c-b4f6-f2c07655cbe2']},
#  {'id': 'ef679120-f454-4843-af72-f6621cf43b9c',
#   'index': 54,
#   'period': 1,
#   'timestamp': '00:01:05.091',
#   'minute': 1,
#   'second': 5,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [117.4, 73.4],
#   'duration': 0.0},
#  {'id': '2b99cf4f-3067-4e15-b1f0-9924114dbd55',
#   'index': 55,
#   'period': 1,
#   'timestamp': '00:01:05.091',
#   'minute': 1,
#   'second': 5,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [117.4, 73.4],
#   'duration': 2.4325,
#   'under_pressure': True,
#   'related_events': ['b50ec51e-8d4f-4e09-ba1e-193f39c84955',
#    'cb377bd2-8399-4a1f-ad7b-7f09b345825c',
#    'ef679120-f454-4843-af72-f6621cf43b9c'],
#   'carry': {'end_location': [116.2, 77.7]}},
#  {'id': 'cb377bd2-8399-4a1f-ad7b-7f09b345825c',
#   'index': 56,
#   'period': 1,
#   'timestamp': '00:01:05.212',
#   'minute': 1,
#   'second': 5,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [4.8, 4.8],
#   'duration': 2.0719,
#   'related_events': ['2b99cf4f-3067-4e15-b1f0-9924114dbd55']},
#  {'id': 'b50ec51e-8d4f-4e09-ba1e-193f39c84955',
#   'index': 57,
#   'period': 1,
#   'timestamp': '00:01:07.524',
#   'minute': 1,
#   'second': 7,
#   'type': {'id': 3, 'name': 'Dispossessed'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [116.2, 77.7],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['a0d16570-c9f3-4493-974e-3a3a1c183caa']},
#  {'id': 'a0d16570-c9f3-4493-974e-3a3a1c183caa',
#   'index': 58,
#   'period': 1,
#   'timestamp': '00:01:07.524',
#   'minute': 1,
#   'second': 7,
#   'type': {'id': 4, 'name': 'Duel'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [4.8, 3.3],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['b50ec51e-8d4f-4e09-ba1e-193f39c84955'],
#   'duel': {'outcome': {'id': 13, 'name': 'Lost In Play'},
#    'type': {'id': 11, 'name': 'Tackle'}}},
#  {'id': '9a6037d2-e1e0-4430-9071-1db4b92569ed',
#   'index': 59,
#   'period': 1,
#   'timestamp': '00:01:08.610',
#   'minute': 1,
#   'second': 8,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [3.8, 5.7],
#   'duration': 2.653991,
#   'related_events': ['4ad37e61-8c5c-41b9-a283-523d1b35aa2a',
#    'f646be7e-a43b-4cb4-aa6e-75e9da918ed9']},
#  {'id': 'f646be7e-a43b-4cb4-aa6e-75e9da918ed9',
#   'index': 60,
#   'period': 1,
#   'timestamp': '00:01:10.321',
#   'minute': 1,
#   'second': 10,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [115.5, 77.7],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['9a6037d2-e1e0-4430-9071-1db4b92569ed']},
#  {'id': '4ad37e61-8c5c-41b9-a283-523d1b35aa2a',
#   'index': 61,
#   'period': 1,
#   'timestamp': '00:01:10.321',
#   'minute': 1,
#   'second': 10,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [115.5, 77.7],
#   'duration': 1.0238,
#   'under_pressure': True,
#   'related_events': ['48e01960-e6be-49c8-bc68-77ad060d0109',
#    '9a6037d2-e1e0-4430-9071-1db4b92569ed',
#    'f646be7e-a43b-4cb4-aa6e-75e9da918ed9'],
#   'carry': {'end_location': [116.2, 76.0]}},
#  {'id': '48e01960-e6be-49c8-bc68-77ad060d0109',
#   'index': 62,
#   'period': 1,
#   'timestamp': '00:01:11.344',
#   'minute': 1,
#   'second': 11,
#   'type': {'id': 3, 'name': 'Dispossessed'},
#   'possession': 4,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [116.2, 76.0],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['6b136656-4838-4bc7-a585-7fdb434c815a']},
#  {'id': '6b136656-4838-4bc7-a585-7fdb434c815a',
#   'index': 63,
#   'period': 1,
#   'timestamp': '00:01:11.344',
#   'minute': 1,
#   'second': 11,
#   'type': {'id': 4, 'name': 'Duel'},
#   'possession': 5,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [4.8, 5.0],
#   'duration': 0.0,
#   'under_pressure': True,
#   'counterpress': True,
#   'related_events': ['48e01960-e6be-49c8-bc68-77ad060d0109'],
#   'duel': {'outcome': {'id': 16, 'name': 'Success In Play'},
#    'type': {'id': 11, 'name': 'Tackle'}}},
#  {'id': '252cda6f-425a-48fb-aa44-7b4085443315',
#   'index': 64,
#   'period': 1,
#   'timestamp': '00:01:11.763',
#   'minute': 1,
#   'second': 11,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10190, 'name': 'Jade Moore'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [5.2, 8.3],
#   'duration': 1.2726,
#   'related_events': ['b799deda-4bc3-4db9-96f2-b7a5169aef4a'],
#   'pass': {'recipient': {'id': 15619, 'name': 'Bethany Mead'},
#    'length': 6.26099,
#    'angle': -0.4636476,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [10.8, 5.5],
#    'deflected': True,
#    'type': {'id': 66, 'name': 'Recovery'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '01c7aa58-d2fd-464a-a6d0-6b82d02957e3',
#   'index': 65,
#   'period': 1,
#   'timestamp': '00:01:12.673',
#   'minute': 1,
#   'second': 12,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 5,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 24693, 'name': 'Hanna Glas'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [114.6, 73.0],
#   'duration': 0.473453,
#   'counterpress': True,
#   'related_events': ['69c71147-c26c-482c-9fe5-c534f83abf87',
#    '9e5c4e80-0a9e-49ed-82fd-f0db54e40a9c',
#    'b799deda-4bc3-4db9-96f2-b7a5169aef4a']},
#  {'id': 'b799deda-4bc3-4db9-96f2-b7a5169aef4a',
#   'index': 66,
#   'period': 1,
#   'timestamp': '00:01:13.036',
#   'minute': 1,
#   'second': 13,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 15619, 'name': 'Bethany Mead'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'location': [10.8, 5.5],
#   'under_pressure': True,
#   'related_events': ['01c7aa58-d2fd-464a-a6d0-6b82d02957e3',
#    '252cda6f-425a-48fb-aa44-7b4085443315']},
#  {'id': '69c71147-c26c-482c-9fe5-c534f83abf87',
#   'index': 67,
#   'period': 1,
#   'timestamp': '00:01:13.036',
#   'minute': 1,
#   'second': 13,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 15619, 'name': 'Bethany Mead'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'location': [10.8, 5.5],
#   'duration': 0.1089,
#   'under_pressure': True,
# ...
#   'possession': 53,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10229, 'name': 'Stina Blackstenius'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [108.3, 17.7],
#   'duration': 3.9884,
#   'under_pressure': True,
#   'related_events': ['504fff3a-5a1e-460a-8bc2-56f853e6463f',
#    '52195dcd-947e-48db-8d11-72c014a7ba46'],
#   'pass': {'recipient': {'id': 13881, 'name': 'Eva Sofia Jakobsson'},
#    'length': 47.68312,
#    'angle': 1.3207313,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [120.1, 63.9],
#    'cross': True,
#    'switch': True,
#    'outcome': {'id': 75, 'name': 'Out'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '52195dcd-947e-48db-8d11-72c014a7ba46',
#   'index': 979,
#   'period': 1,
#   'timestamp': '00:31:37.794',
#   'minute': 31,
#   'second': 37,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 53,
#   'possession_team': {'id': 858, 'name': "Sweden Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 13881, 'name': 'Eva Sofia Jakobsson'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [116.6, 46.4],
#   'related_events': ['4e3e5e50-33e7-4dfa-9ef3-5bd77c6c23b7'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '45354a47-a688-484b-8839-40b1c36a5e8e',
#   'index': 980,
#   'period': 1,
#   'timestamp': '00:32:03.024',
#   'minute': 32,
#   'second': 3,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 19421, 'name': 'Carly Mitchell Telford'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [6.0, 36.0],
#   'duration': 2.9442,
#   'related_events': ['85f95f2b-d9ec-4d82-b165-86f8d4620196'],
#   'pass': {'recipient': {'id': 10172, 'name': 'Jill Scott'},
#    'length': 61.43175,
#    'angle': 0.5460029,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [58.5, 67.9],
#    'type': {'id': 63, 'name': 'Goal Kick'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '85f95f2b-d9ec-4d82-b165-86f8d4620196',
#   'index': 981,
#   'period': 1,
#   'timestamp': '00:32:05.968',
#   'minute': 32,
#   'second': 5,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10172, 'name': 'Jill Scott'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [58.5, 67.9],
#   'related_events': ['45354a47-a688-484b-8839-40b1c36a5e8e']},
#  {'id': '098cf399-80a7-44e2-847b-3924bb4f218b',
#   'index': 982,
#   'period': 1,
#   'timestamp': '00:32:05.968',
#   'minute': 32,
#   'second': 5,
#   'type': {'id': 4, 'name': 'Duel'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 10224, 'name': 'Sara Caroline Seger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [63.4, 12.5],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['790b8e6a-566f-484b-a1cf-c8771533bc16'],
#   'duel': {'type': {'id': 10, 'name': 'Aerial Lost'}}},
#  {'id': '790b8e6a-566f-484b-a1cf-c8771533bc16',
#   'index': 983,
#   'period': 1,
#   'timestamp': '00:32:05.968',
#   'minute': 32,
#   'second': 5,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10172, 'name': 'Jill Scott'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [57.6, 68.5],
#   'duration': 1.161396,
#   'under_pressure': True,
#   'related_events': ['098cf399-80a7-44e2-847b-3924bb4f218b',
#    'f6a2234c-4967-4116-8666-36df2051caba'],
#   'pass': {'recipient': {'id': 10180, 'name': 'Ellen White'},
#    'length': 16.360012,
#    'angle': -0.2850166,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [73.3, 63.9],
#    'aerial_won': True}},
#  {'id': 'f6a2234c-4967-4116-8666-36df2051caba',
#   'index': 984,
#   'period': 1,
#   'timestamp': '00:32:07.129',
#   'minute': 32,
#   'second': 7,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10180, 'name': 'Ellen White'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [73.3, 63.9],
#   'related_events': ['790b8e6a-566f-484b-a1cf-c8771533bc16']},
#  {'id': '83c8fa91-144f-4472-9915-c2a0437fdd94',
#   'index': 985,
#   'period': 1,
#   'timestamp': '00:32:07.129',
#   'minute': 32,
#   'second': 7,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10180, 'name': 'Ellen White'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [73.3, 63.9],
#   'duration': 1.040404,
#   'related_events': ['0d097bc5-886d-4001-98ef-873fdc8fb5ae',
#    'f6a2234c-4967-4116-8666-36df2051caba'],
#   'carry': {'end_location': [77.5, 64.0]}},
#  {'id': '0d097bc5-886d-4001-98ef-873fdc8fb5ae',
#   'index': 986,
#   'period': 1,
#   'timestamp': '00:32:08.170',
#   'minute': 32,
#   'second': 8,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10180, 'name': 'Ellen White'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [77.5, 64.0],
#   'duration': 1.010562,
#   'related_events': ['1b1149d7-c70f-4be2-849c-817405f970cd'],
#   'pass': {'recipient': {'id': 4654, 'name': 'Nikita Parris'},
#    'length': 9.261749,
#    'angle': 0.9078592,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [83.2, 71.3],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '1b1149d7-c70f-4be2-849c-817405f970cd',
#   'index': 987,
#   'period': 1,
#   'timestamp': '00:32:09.180',
#   'minute': 32,
#   'second': 9,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4654, 'name': 'Nikita Parris'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'location': [83.2, 71.3],
#   'related_events': ['0d097bc5-886d-4001-98ef-873fdc8fb5ae']},
#  {'id': '85f7cb1a-aea6-4235-9103-702d94c92f30',
#   'index': 988,
#   'period': 1,
#   'timestamp': '00:32:09.180',
#   'minute': 32,
#   'second': 9,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4654, 'name': 'Nikita Parris'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'location': [83.2, 71.3],
#   'duration': 2.071938,
#   'related_events': ['1b1149d7-c70f-4be2-849c-817405f970cd',
#    'df5998a4-67d7-48a7-a79c-bb82a8010fe2'],
#   'carry': {'end_location': [83.8, 61.4]}},
#  {'id': 'df5998a4-67d7-48a7-a79c-bb82a8010fe2',
#   'index': 989,
#   'period': 1,
#   'timestamp': '00:32:11.252',
#   'minute': 32,
#   'second': 11,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 4654, 'name': 'Nikita Parris'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'location': [83.8, 61.4],
#   'duration': 0.899748,
#   'related_events': ['834a3439-25d2-4ec1-bac5-e691d9144f23'],
#   'pass': {'recipient': {'id': 10190, 'name': 'Jade Moore'},
#    'length': 11.1,
#    'angle': -1.5707964,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [83.8, 50.3],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '834a3439-25d2-4ec1-bac5-e691d9144f23',
#   'index': 990,
#   'period': 1,
#   'timestamp': '00:32:12.152',
#   'minute': 32,
#   'second': 12,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10190, 'name': 'Jade Moore'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [83.8, 50.3],
#   'related_events': ['df5998a4-67d7-48a7-a79c-bb82a8010fe2']},
#  {'id': '3dbfbeea-c1d4-4685-bc62-042775fbc923',
#   'index': 991,
#   'period': 1,
#   'timestamp': '00:32:12.152',
#   'minute': 32,
#   'second': 12,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10190, 'name': 'Jade Moore'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [83.8, 50.3],
#   'duration': 4.229752,
#   'under_pressure': True,
#   'related_events': ['3e820863-642d-41ae-969d-ccddf5283533',
#    '4919cfd2-3b88-4893-a45e-ed811ae495cc',
#    '834a3439-25d2-4ec1-bac5-e691d9144f23'],
#   'carry': {'end_location': [76.7, 24.8]}},
#  {'id': '4919cfd2-3b88-4893-a45e-ed811ae495cc',
#   'index': 992,
#   'period': 1,
#   'timestamp': '00:32:13.183',
#   'minute': 32,
#   'second': 13,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 858, 'name': "Sweden Women's"},
#   'player': {'id': 26093, 'name': 'Nathalie Bj̦rn'},
#   'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#   'location': [34.1, 38.4],
#   'duration': 1.105559,
#   'related_events': ['3dbfbeea-c1d4-4685-bc62-042775fbc923']},
#  {'id': '3e820863-642d-41ae-969d-ccddf5283533',
#   'index': 993,
#   'period': 1,
#   'timestamp': '00:32:16.382',
#   'minute': 32,
#   'second': 16,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10190, 'name': 'Jade Moore'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [76.7, 24.8],
#   'duration': 1.025086,
#   'related_events': ['195b1365-9486-4a35-926b-85f199a656bc'],
#   'pass': {'recipient': {'id': 10252, 'name': 'Alex Greenwood'},
#    'length': 14.653668,
#    'angle': -1.7909456,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [73.5, 10.5],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '195b1365-9486-4a35-926b-85f199a656bc',
#   'index': 994,
#   'period': 1,
#   'timestamp': '00:32:17.407',
#   'minute': 32,
#   'second': 17,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [73.5, 10.5],
#   'related_events': ['3e820863-642d-41ae-969d-ccddf5283533']},
#  {'id': '92f13883-c119-4419-a904-d4c4742d586c',
#   'index': 995,
#   'period': 1,
#   'timestamp': '00:32:17.407',
#   'minute': 32,
#   'second': 17,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [73.5, 10.5],
#   'duration': 3.670014,
#   'related_events': ['195b1365-9486-4a35-926b-85f199a656bc',
#    '358b947f-e744-4a38-99fe-9f82aab70c06'],
#   'carry': {'end_location': [84.6, 8.2]}},
#  {'id': '358b947f-e744-4a38-99fe-9f82aab70c06',
#   'index': 996,
#   'period': 1,
#   'timestamp': '00:32:21.077',
#   'minute': 32,
#   'second': 21,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10252, 'name': 'Alex Greenwood'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [84.6, 8.2],
#   'duration': 0.620102,
#   'related_events': ['e1687b8a-50e6-43f4-b430-bba161727af7'],
#   'pass': {'recipient': {'id': 15619, 'name': 'Bethany Mead'},
#    'length': 7.420243,
#    'angle': -0.9192091,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [89.1, 2.3],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'e1687b8a-50e6-43f4-b430-bba161727af7',
#   'index': 997,
#   'period': 1,
#   'timestamp': '00:32:21.697',
#   'minute': 32,
#   'second': 21,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 15619, 'name': 'Bethany Mead'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'location': [89.1, 2.3],
#   'related_events': ['358b947f-e744-4a38-99fe-9f82aab70c06']},
#  {'id': '4d307565-af0b-4c1e-81a4-d6fcbbc7bec1',
#   'index': 998,
#   'period': 1,
#   'timestamp': '00:32:21.697',
#   'minute': 32,
#   'second': 21,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 15619, 'name': 'Bethany Mead'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'location': [89.1, 2.3],
#   'duration': 1.953598,
#   'related_events': ['ac4d6a87-07c3-4127-9962-23a4813beac5',
#    'e1687b8a-50e6-43f4-b430-bba161727af7'],
#   'carry': {'end_location': [89.5, 7.7]}},
#  {'id': 'ac4d6a87-07c3-4127-9962-23a4813beac5',
#   'index': 999,
#   'period': 1,
#   'timestamp': '00:32:23.651',
#   'minute': 32,
#   'second': 23,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 15619, 'name': 'Bethany Mead'},
#   'position': {'id': 16, 'name': 'Left Midfield'},
#   'location': [89.5, 7.7],
#   'duration': 3.4236,
#   'related_events': ['908707f5-5e99-4017-b85c-18ebd9883d91'],
#   'pass': {'recipient': {'id': 10180, 'name': 'Ellen White'},
#    'length': 29.923235,
#    'angle': 0.94200003,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [107.1, 31.9],
#    'cross': True,
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '908707f5-5e99-4017-b85c-18ebd9883d91',
#   'index': 1000,
#   'period': 1,
#   'timestamp': '00:32:27.074',
#   'minute': 32,
#   'second': 27,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 54,
#   'possession_team': {'id': 865, 'name': "England Women's"},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 865, 'name': "England Women's"},
#   'player': {'id': 10180, 'name': 'Ellen White'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [107.1, 31.9],
#   'related_events': ['ac4d6a87-07c3-4127-9962-23a4813beac5']},
#  ...]

# %%
from pandas import json_normalize
df=json_normalize(data,sep="_")

# %%
df.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  e8643796-c76d-44f5-a03d-fa742e051942      1       1  00:00:00.000       0
# 1  937f83f8-674d-4c58-81d5-e2101a9f2e60      2       1  00:00:00.000       0
# 2  87ba272a-3af0-4fc7-872f-65e8f79fb753      3       1  00:00:00.000       0
# 3  85d30bef-8b77-405e-bc64-c63ed4d7a6d7      4       1  00:00:00.000       0
# 4  760528a6-2de2-427f-9795-b2b19819ef1f      5       1  00:00:00.140       0
#
#    second  possession  duration  type_id    type_name  ...  pass_cut_back  \
# 0       0           1   0.00000       35  Starting XI  ...            NaN
# 1       0           1   0.00000       35  Starting XI  ...            NaN
# 2       0           1   0.00000       18   Half Start  ...            NaN
# 3       0           1   0.00000       18   Half Start  ...            NaN
# 4       0           2   0.16873       30         Pass  ...            NaN
#
#   bad_behaviour_card_id  bad_behaviour_card_name pass_no_touch  pass_straight  \
# 0                   NaN                      NaN           NaN            NaN
# 1                   NaN                      NaN           NaN            NaN
# 2                   NaN                      NaN           NaN            NaN
# 3                   NaN                      NaN           NaN            NaN
# 4                   NaN                      NaN           NaN            NaN
#
#   block_save_block  foul_committed_advantage foul_won_advantage  \
# 0              NaN                       NaN                NaN
# 1              NaN                       NaN                NaN
# 2              NaN                       NaN                NaN
# 3              NaN                       NaN                NaN
# 4              NaN                       NaN                NaN
#
#   foul_committed_card_id foul_committed_card_name
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
# [5 rows x 119 columns]

# %%
shots=df.loc[df["type_name"]=="Shot"].set_index("id")

# %%
shots
# Out:
#                                       index  period     timestamp  minute  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764    340       1  00:10:24.396      10
# de5c41c5-9200-439e-b051-bfe2016d689a    531       1  00:15:28.174      15
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5    720       1  00:21:08.216      21
# 309f6f06-3977-49ac-8c0b-0e31b54404ed    742       1  00:22:46.449      22
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd    956       1  00:30:38.174      30
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede   1327       1  00:43:53.832      43
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1   1485       1  00:48:48.810      48
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa   1577       1  00:50:54.516      50
# 9a3c4fba-3223-4305-a06b-e08f52796c34   1783       2  00:04:49.997      49
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd   1795       2  00:04:55.985      49
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b   2012       2  00:11:48.692      56
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e   2205       2  00:16:32.408      61
# 9fe6251c-6b05-4f27-bcda-2042f7dce864   2262       2  00:18:35.122      63
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f   2326       2  00:20:50.777      65
# 9c5e8a81-051b-440b-9aad-dd704587ee30   2962       2  00:37:19.021      82
# 435009e3-0653-45e3-95f6-f4215613adab   3094       2  00:42:29.326      87
# d68b860f-d159-4a6f-b53f-b49b024c9399   3120       2  00:44:02.250      89
# ee3a7d47-de33-4a21-9dc1-927571c52729   3169       2  00:45:17.335      90
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0   3197       2  00:45:56.103      90
#
#                                       second  possession  duration  type_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764      24          18  1.342346       16
# de5c41c5-9200-439e-b051-bfe2016d689a      28          25  0.472900       16
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5       8          35  1.254112       16
# 309f6f06-3977-49ac-8c0b-0e31b54404ed      46          37  1.118733       16
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd      38          52  1.359400       16
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede      53          75  1.828469       16
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1      48          83  2.337809       16
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa      54          88  0.454200       16
# 9a3c4fba-3223-4305-a06b-e08f52796c34      49         102  0.515500       16
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd      55         102  1.399900       16
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b      48         117  0.222300       16
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e      32         126  1.311600       16
# 9fe6251c-6b05-4f27-bcda-2042f7dce864      35         132  4.693700       16
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f      50         138  0.821417       16
# 9c5e8a81-051b-440b-9aad-dd704587ee30      19         172  1.717500       16
# 435009e3-0653-45e3-95f6-f4215613adab      29         181  0.901313       16
# d68b860f-d159-4a6f-b53f-b49b024c9399       2         189  0.502900       16
# ee3a7d47-de33-4a21-9dc1-927571c52729      17         191  1.339000       16
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0      56         193  0.382200       16
#
#                                      type_name  possession_team_id  ...  \
# id                                                                  ...
# f158cbc0-a7a1-4787-8f73-15c66ae55764      Shot                 858  ...
# de5c41c5-9200-439e-b051-bfe2016d689a      Shot                 858  ...
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5      Shot                 858  ...
# 309f6f06-3977-49ac-8c0b-0e31b54404ed      Shot                 865  ...
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd      Shot                 865  ...
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede      Shot                 858  ...
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1      Shot                 858  ...
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa      Shot                 865  ...
# 9a3c4fba-3223-4305-a06b-e08f52796c34      Shot                 865  ...
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd      Shot                 865  ...
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b      Shot                 865  ...
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e      Shot                 865  ...
# 9fe6251c-6b05-4f27-bcda-2042f7dce864      Shot                 858  ...
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f      Shot                 858  ...
# 9c5e8a81-051b-440b-9aad-dd704587ee30      Shot                 858  ...
# 435009e3-0653-45e3-95f6-f4215613adab      Shot                 858  ...
# d68b860f-d159-4a6f-b53f-b49b024c9399      Shot                 865  ...
# ee3a7d47-de33-4a21-9dc1-927571c52729      Shot                 865  ...
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0      Shot                 865  ...
#
#                                      bad_behaviour_card_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                   NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                   NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                   NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                   NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                   NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                   NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                   NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                   NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                   NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                   NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                   NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                   NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                   NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                   NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                   NaN
# 435009e3-0653-45e3-95f6-f4215613adab                   NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                   NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                   NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                   NaN
#
#                                       bad_behaviour_card_name pass_no_touch  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                      NaN           NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                      NaN           NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                      NaN           NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                      NaN           NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                      NaN           NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                      NaN           NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                      NaN           NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                      NaN           NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                      NaN           NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                      NaN           NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                      NaN           NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                      NaN           NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                      NaN           NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                      NaN           NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                      NaN           NaN
# 435009e3-0653-45e3-95f6-f4215613adab                      NaN           NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                      NaN           NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                      NaN           NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                      NaN           NaN
#
#                                       pass_straight block_save_block  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764            NaN              NaN
# de5c41c5-9200-439e-b051-bfe2016d689a            NaN              NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5            NaN              NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed            NaN              NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd            NaN              NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede            NaN              NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1            NaN              NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa            NaN              NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34            NaN              NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd            NaN              NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b            NaN              NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e            NaN              NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864            NaN              NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f            NaN              NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30            NaN              NaN
# 435009e3-0653-45e3-95f6-f4215613adab            NaN              NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399            NaN              NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729            NaN              NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0            NaN              NaN
#
#                                       foul_committed_advantage  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                       NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                       NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                       NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                       NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                       NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                       NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                       NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                       NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                       NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                       NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                       NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                       NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                       NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                       NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                       NaN
# 435009e3-0653-45e3-95f6-f4215613adab                       NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                       NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                       NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                       NaN
#
#                                      foul_won_advantage  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                NaN
# 435009e3-0653-45e3-95f6-f4215613adab                NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                NaN
#
#                                      foul_committed_card_id  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                    NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                    NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                    NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                    NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                    NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                    NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                    NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                    NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                    NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                    NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                    NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                    NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                    NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                    NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                    NaN
# 435009e3-0653-45e3-95f6-f4215613adab                    NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                    NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                    NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                    NaN
#
#                                      foul_committed_card_name  \
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764                      NaN
# de5c41c5-9200-439e-b051-bfe2016d689a                      NaN
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5                      NaN
# 309f6f06-3977-49ac-8c0b-0e31b54404ed                      NaN
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd                      NaN
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede                      NaN
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1                      NaN
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa                      NaN
# 9a3c4fba-3223-4305-a06b-e08f52796c34                      NaN
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd                      NaN
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b                      NaN
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e                      NaN
# 9fe6251c-6b05-4f27-bcda-2042f7dce864                      NaN
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f                      NaN
# 9c5e8a81-051b-440b-9aad-dd704587ee30                      NaN
# 435009e3-0653-45e3-95f6-f4215613adab                      NaN
# d68b860f-d159-4a6f-b53f-b49b024c9399                      NaN
# ee3a7d47-de33-4a21-9dc1-927571c52729                      NaN
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0                      NaN
#
#                                                          match_id
# id
# f158cbc0-a7a1-4787-8f73-15c66ae55764  Statsbomb/data/events/69301
# de5c41c5-9200-439e-b051-bfe2016d689a  Statsbomb/data/events/69301
# 106faebb-00bc-4453-b1c1-1bacdb1ebbc5  Statsbomb/data/events/69301
# 309f6f06-3977-49ac-8c0b-0e31b54404ed  Statsbomb/data/events/69301
# d1c8dbc7-a164-4e34-8674-1eeba842cbbd  Statsbomb/data/events/69301
# 38ac2346-ce1d-4d7a-9dcc-39d337eebede  Statsbomb/data/events/69301
# 7f6c533d-e8d4-4810-8be6-e3183e3caea1  Statsbomb/data/events/69301
# 79e0c6d1-9640-420a-8ba8-d0304b1f24fa  Statsbomb/data/events/69301
# 9a3c4fba-3223-4305-a06b-e08f52796c34  Statsbomb/data/events/69301
# cb2480d3-d896-4568-9fb5-d0a4d1a70ddd  Statsbomb/data/events/69301
# d3c5e620-8fa9-4c0b-8fd8-a6c95463c53b  Statsbomb/data/events/69301
# 300ca316-03cf-4aa1-b12c-68d91ffb6f1e  Statsbomb/data/events/69301
# 9fe6251c-6b05-4f27-bcda-2042f7dce864  Statsbomb/data/events/69301
# 8ea1599d-6dc6-4e00-8d51-2f28f41a3d6f  Statsbomb/data/events/69301
# 9c5e8a81-051b-440b-9aad-dd704587ee30  Statsbomb/data/events/69301
# 435009e3-0653-45e3-95f6-f4215613adab  Statsbomb/data/events/69301
# d68b860f-d159-4a6f-b53f-b49b024c9399  Statsbomb/data/events/69301
# ee3a7d47-de33-4a21-9dc1-927571c52729  Statsbomb/data/events/69301
# 1b0b67f2-c8aa-4286-a0a6-58bf0389c5a0  Statsbomb/data/events/69301
#
# [19 rows x 119 columns]

# %%
from matplotlib.patches import Arc
#Create figure
fig=plt.figure(figsize=(12,9))
ax=fig.add_subplot(1,1,1)
#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")    
#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")   
#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")    
#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")
#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")
#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")
#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)
#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")
#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)
#Tidy Axes
plt.axis('off')   
#plot the shots
for i,shot in shots.iterrows():
    x=shot["location"][0]
    y=shot["location"][1]
    goal=shot["shot_outcome_name"]=="Goal"
    team_name=shot["team_name"]
    #circlesize=2
    circlesize=np.sqrt(shot["shot_statsbomb_xg"])*12
    if(team_name==home_team_required):
        if goal:
            shotcircle=plt.Circle((x,width-y),circlesize,color="red")
            plt.text((x+1),width-y+1,shot["player_name"])
        else:
            shotcircle=plt.Circle((x,width-y),circlesize,color="red")
            shotcircle.set_alpha(0.2)
    elif (team_name==away_team_required):
        if goal:
            shotcircle=plt.Circle((length-x,y),circlesize,color="blue")
            plt.text((length-x+1),y+1,shot["player_name"])
        else:
            shotcircle=plt.Circle((length-x,y),circlesize,color="blue")
            shotcircle.set_alpha(0.2)
    ax.add_patch(shotcircle)
plt.text(5,75,away_team_required + ' shots') 
plt.text(80,75,home_team_required + ' shots') 

#Display Pitch
plt.show()

# %%
home_team_required="England Women's"
away_team_required="Sweden Women's"

# %%
#Find the passes
passes = df.loc[df['type_name'] == 'Pass'].set_index('id')
#Draw the pitch
#Create figure
fig=plt.figure(figsize=(12,9))
ax=fig.add_subplot(1,1,1)
#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")    
#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")   
#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")    
#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")
#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")
#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")
#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)
#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")
#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)
#Tidy Axes
plt.axis('off')   
for i,thepass in passes.iterrows():
    #if thepass['team_name']==away_team_required: #
    if thepass['player_name']=='Lucy Bronze':
        x=thepass['location'][0]
        y=thepass['location'][1]
        passCircle=plt.Circle((x,width-y),2,color="blue")      
        passCircle.set_alpha(.2)   
        ax.add_patch(passCircle)
        dx=thepass['pass_end_location'][0]-x
        dy=thepass['pass_end_location'][1]-y

        passArrow=plt.Arrow(x,width-y,dx,-dy,width=3,color="blue")
        ax.add_patch(passArrow)

fig.set_size_inches(10, 7)
plt.title("passses made by lucy bronze")
plt.show()
